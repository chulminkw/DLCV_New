# %% [markdown]
# ### Yolo v5 다운로드 및 설치

# %%
# !git clone https://github.com/ultralytics/yolov5
# !cd yolov5;pip install -qr requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 7053, done.
# remote: Counting objects: 100% (159/159), done.
# remote: Compressing objects: 100% (102/102), done.
# remote: Total 7053 (delta 87), reused 109 (delta 57), pack-reused 6894
# Receiving objects: 100% (7053/7053), 9.14 MiB | 12.17 MiB/s, done.
# Resolving deltas: 100% (4826/4826), done.
#      |████████████████████████████████| 645kB 4.3MB/s

# %% [markdown]
# ### XML 포맷의 BCCD 데이터 세트를 다운로드 후 voc2coco를 이용하여 ms-coco 형태로 변환.

# %%
import os

# !git clone https://github.com/Shenggan/BCCD_Dataset.git
# !git clone https://github.com/yukkyo/voc2coco.git

# colab 버전은 아래 명령어로 BCCD의 labels.txt를 생성합니다.  
with open('/content/BCCD_Dataset/BCCD/labels.txt', "w") as f:
    f.write("WBC\n")
    f.write("RBC\n")
    f.write("Platelets\n")

# !cat /content/BCCD_Dataset/BCCD/labels.txt

# VOC를 COCO로 변환 수행. 학습/검증/테스트 용 json annotation을 생성. 
# %cd voc2coco
# !python voc2coco.py --ann_dir /content/BCCD_Dataset/BCCD/Annotations \
--ann_ids /content/BCCD_Dataset/BCCD/ImageSets/Main/train.txt \
--labels /content/BCCD_Dataset/BCCD/labels.txt \
--output /content/BCCD_Dataset/BCCD/train.json \
--ext xml

# !python voc2coco.py --ann_dir /content/BCCD_Dataset/BCCD/Annotations \
--ann_ids /content/BCCD_Dataset/BCCD/ImageSets/Main/val.txt \
--labels /content/BCCD_Dataset/BCCD/labels.txt \
--output /content/BCCD_Dataset/BCCD/val.json \
--ext xml

# !python voc2coco.py --ann_dir /content/BCCD_Dataset/BCCD/Annotations \
--ann_ids /content/BCCD_Dataset/BCCD/ImageSets/Main/test.txt \
--labels /content/BCCD_Dataset/BCCD/labels.txt \
--output /content/BCCD_Dataset/BCCD/test.json \
--ext xml

# annotation json 파일을 잘 볼수 있는 jq 유틸리티 셋업. 
# !sudo apt-get install jq
# !jq . /content/BCCD_Dataset/BCCD/train.json > output.json
# !tail -100 output.json
# Out:
# Cloning into 'BCCD_Dataset'...
# remote: Enumerating objects: 800, done.
# remote: Total 800 (delta 0), reused 0 (delta 0), pack-reused 800
# Receiving objects: 100% (800/800), 7.39 MiB | 15.63 MiB/s, done.
# Resolving deltas: 100% (378/378), done.
# Cloning into 'voc2coco'...
# remote: Enumerating objects: 420, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 420 (delta 3), reused 8 (delta 3), pack-reused 409
# Receiving objects: 100% (420/420), 213.31 KiB | 1.36 MiB/s, done.
# Resolving deltas: 100% (379/379), done.
# WBC
# RBC
# Platelets
# /content/voc2coco
# Start converting !
# 100% 205/205 [00:00<00:00, 4148.49it/s]
# Start converting !
# 100% 87/87 [00:00<00:00, 4458.59it/s]
# Start converting !
# 100% 72/72 [00:00<00:00, 5277.51it/s]
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libjq1 libonig4
# The following NEW packages will be installed:
#   jq libjq1 libonig4
# 0 upgraded, 3 newly installed, 0 to remove and 39 not upgraded.
# Need to get 276 kB of archives.
# After this operation, 930 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libonig4 amd64 6.7.0-1 [119 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libjq1 amd64 1.5+dfsg-2 [111 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 jq amd64 1.5+dfsg-2 [45.6 kB]
# Fetched 276 kB in 2s (143 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 3.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libonig4:amd64.
# (Reading database ... 160772 files and directories currently installed.)
# Preparing to unpack .../libonig4_6.7.0-1_amd64.deb ...
# Unpacking libonig4:amd64 (6.7.0-1) ...
# Selecting previously unselected package libjq1:amd64.
# Preparing to unpack .../libjq1_1.5+dfsg-2_amd64.deb ...
# Unpacking libjq1:amd64 (1.5+dfsg-2) ...
# Selecting previously unselected package jq.
# Preparing to unpack .../jq_1.5+dfsg-2_amd64.deb ...
# Unpacking jq (1.5+dfsg-2) ...
# Setting up libonig4:amd64 (6.7.0-1) ...
# Setting up libjq1:amd64 (1.5+dfsg-2) ...
# Setting up jq (1.5+dfsg-2) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00408",
#       "id": 2800
#     },
#     {
#       "area": 9405,
#       "iscrowd": 0,
#       "bbox": [
#         102,
#         0,
#         99,
#         95
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00408",
#       "id": 2801
#     },
#     {
#       "area": 7128,
#       "iscrowd": 0,
#       "bbox": [
#         197,
#         0,
#         88,
#         81
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00408",
#       "id": 2802
#     },
#     {
#       "area": 756,
#       "iscrowd": 0,
#       "bbox": [
#         0,
#         280,
#         21,
#         36
#       ],
#       "category_id": 3,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00408",
#       "id": 2803
#     },
#     {
#       "area": 1302,
#       "iscrowd": 0,
#       "bbox": [
#         382,
#         253,
#         42,
#         31
#       ],
#       "category_id": 3,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00408",
#       "id": 2804
#     },
#     {
#       "area": 42120,
#       "iscrowd": 0,
#       "bbox": [
#         309,
#         318,
#         260,
#         162
#       ],
#       "category_id": 1,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00408",
#       "id": 2805
#     }
#   ],
#   "categories": [
#     {
#       "supercategory": "none",
#       "id": 1,
#       "name": "WBC"
#     },
#     {
#       "supercategory": "none",
#       "id": 2,
#       "name": "RBC"
#     },
#     {
#       "supercategory": "none",
#       "id": 3,
#       "name": "Platelets"
#     }
#   ]
# }

# %%
# !head -100 output.json
# Out:
# {
#   "images": [
#     {
#       "file_name": "BloodImage_00001.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00001"
#     },
#     {
#       "file_name": "BloodImage_00003.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00003"
#     },
#     {
#       "file_name": "BloodImage_00004.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00004"
#     },
#     {
#       "file_name": "BloodImage_00005.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00005"
#     },
#     {
#       "file_name": "BloodImage_00006.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00006"
#     },
#     {
#       "file_name": "BloodImage_00008.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00008"
#     },
#     {
#       "file_name": "BloodImage_00009.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00009"
#     },
#     {
#       "file_name": "BloodImage_00010.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00010"
#     },
#     {
#       "file_name": "BloodImage_00012.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00012"
#     },
#     {
#       "file_name": "BloodImage_00013.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00013"
#     },
#     {
#       "file_name": "BloodImage_00020.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00020"
#     },
#     {
#       "file_name": "BloodImage_00022.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00022"
#     },
#     {
#       "file_name": "BloodImage_00023.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00023"
#     },
#     {
#       "file_name": "BloodImage_00024.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00024"
#     },
#     {
#       "file_name": "BloodImage_00026.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00026"
#     },
#     {
#       "file_name": "BloodImage_00032.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00032"
#     },
#     {
#       "file_name": "BloodImage_00034.jpg",

# %%
# %cd /content

# %%
# !git clone https://github.com/alexmihalyk23/COCO2YOLO.git

# %% [markdown]
# ### COCO 포맷을 Ultralytics yolo 포맷으로 변환
# * https://github.com/alexmihalyk23/COCO2YOLO.git 를 약간 수정하여 변환로직 생성.
# * 소스 이미지 디렉토리와 Json annotation 파일, 타겟 이미지 디렉토리, 타겟 annotation 디렉토리를 기반으로 train/val/test Json annotation 파일에 따라 소스 이미지 디렉토리에 있는 파일들은 타겟 이미지 디렉토리로 단순 복사하고, annotation 파일은 yolo 포맷으로 변환하여 타겟 annotation 디렉토리로 저장
# * 한개의 json annotation 파일이 여러개의 yolo 포맷 annotation 파일로 변환됨.
# * Ultralytics 도 JSON2Yolo 를 제공하나, 적용 시 coco dataset의 customization이 별도 필요.

# %%
# https://github.com/alexmihalyk23/COCO2YOLO.git
import json
import os
import shutil

class COCO2YOLO:
  # 소스 이미지 디렉토리와 Json annotation 파일, 타겟 이미지 디렉토리, 타겟 annotation 디렉토리를 생성자로 입력 받음. 
  def __init__(self, src_img_dir, json_file, tgt_img_dir, tgt_anno_dir):
    self.json_file = json_file
    self.src_img_dir = src_img_dir
    self.tgt_img_dir = tgt_img_dir
    self.tgt_anno_dir = tgt_anno_dir
    # json 파일과 타겟 디렉토리가 존재하는지 확인하고, 디렉토리의 경우는 없으면 생성. 
    self._check_file_and_dir(json_file, tgt_img_dir, tgt_anno_dir)
    # json 파일을 메모리로 로딩. 
    self.labels = json.load(open(json_file, 'r', encoding='utf-8'))
    # category id와 이름을 매핑하지만, 실제 class id는 이를 적용하지 않고 별도 적용. 
    self.coco_id_name_map = self._categories()
    self.coco_name_list = list(self.coco_id_name_map.values())
    print("total images", len(self.labels['images']))
    print("total categories", len(self.labels['categories']))
    print("total labels", len(self.labels['annotations']))
  
  # json 파일과 타겟 디렉토리가 존재하는지 확인하고, 디렉토리의 경우는 없으면 생성. 
  def _check_file_and_dir(self, file_path, tgt_img_dir, tgt_anno_dir):
    if not os.path.exists(file_path):
        raise ValueError("file not found")
    if not os.path.exists(tgt_img_dir):
        os.makedirs(tgt_img_dir)
    if not os.path.exists(tgt_anno_dir):
        os.makedirs(tgt_anno_dir)

  # category id와 이름을 매핑하지만, 추후에 class 명만 활용. 
  def _categories(self):
    categories = {}
    for cls in self.labels['categories']:
        categories[cls['id']] = cls['name']
    return categories
  
  # annotation에서 모든 image의 파일명(절대 경로 아님)과 width, height 정보 저장. 
  def _load_images_info(self):
    images_info = {}
    for image in self.labels['images']:
        id = image['id']
        file_name = image['file_name']
        if file_name.find('\\') > -1:
            file_name = file_name[file_name.index('\\')+1:]
        w = image['width']
        h = image['height']
  
        images_info[id] = (file_name, w, h)

    return images_info

  # ms-coco의 bbox annotation은 yolo format으로 변환. 좌상단 x, y좌표, width, height 기반을 정규화된 center x,y 와 width, height로 변환. 
  def _bbox_2_yolo(self, bbox, img_w, img_h):
    # ms-coco는 좌상단 x, y좌표, width, height
    x, y, w, h = bbox[0], bbox[1], bbox[2], bbox[3]
    # center x좌표는 좌상단 x좌표에서 width의 절반을 더함. center y좌표는 좌상단 y좌표에서 height의 절반을 더함.  
    centerx = bbox[0] + w / 2
    centery = bbox[1] + h / 2
    # centerx, centery, width, height를 이미지의 width/height로 정규화. 
    dw = 1 / img_w
    dh = 1 / img_h
    centerx *= dw
    w *= dw
    centery *= dh
    h *= dh
    return centerx, centery, w, h
  
  # image와 annotation 정보를 기반으로 image명과 yolo annotation 정보 가공. 
  # 개별 image당 하나의 annotation 정보를 가지도록 변환. 
  def _convert_anno(self, images_info):
    anno_dict = dict()
    for anno in self.labels['annotations']:
      bbox = anno['bbox']
      image_id = anno['image_id']
      category_id = anno['category_id']

      image_info = images_info.get(image_id)
      image_name = image_info[0]
      img_w = image_info[1]
      img_h = image_info[2]
      yolo_box = self._bbox_2_yolo(bbox, img_w, img_h)

      anno_info = (image_name, category_id, yolo_box)
      anno_infos = anno_dict.get(image_id)
      if not anno_infos:
        anno_dict[image_id] = [anno_info]
      else:
        anno_infos.append(anno_info)
        anno_dict[image_id] = anno_infos
    return anno_dict

  # class 명을 파일로 저장하는 로직. 사용하지 않음. 
  def save_classes(self):
    sorted_classes = list(map(lambda x: x['name'], sorted(self.labels['categories'], key=lambda x: x['id'])))
    print('coco names', sorted_classes)
    with open('coco.names', 'w', encoding='utf-8') as f:
      for cls in sorted_classes:
          f.write(cls + '\n')
    f.close()
  # _convert_anno(images_info)로 만들어진 anno 정보를 개별 yolo anno txt 파일로 생성하는 로직. 
  # coco2yolo()에서 anno_dict = self._convert_anno(images_info)로 만들어진 anno_dict를 _save_txt()에 입력하여 파일 생성
  def _save_txt(self, anno_dict):
    # 개별 image별로 소스 image는 타겟이미지 디렉토리로 복사하고, 개별 annotation을 타겟 anno 디렉토리로 생성. 
    for k, v in anno_dict.items():
      # 소스와 타겟 파일의 절대 경로 생성. 
      src_img_filename = os.path.join(self.src_img_dir, v[0][0])
      tgt_anno_filename = os.path.join(self.tgt_anno_dir,v[0][0].split(".")[0] + ".txt")
      #print('source image filename:', src_img_filename, 'target anno filename:', tgt_anno_filename)
      # 이미지 파일의 경우 타겟 디렉토리로 단순 복사. 
      shutil.copy(src_img_filename, self.tgt_img_dir)
      # 타겟 annotation 출력 파일명으로 classid, bbox 좌표를 object 별로 생성. 
      with open(tgt_anno_filename, 'w', encoding='utf-8') as f:
        #print(k, v)
        # 여러개의 object 별로 classid와 bbox 좌표를 생성. 
        for obj in v:
          cat_name = self.coco_id_name_map.get(obj[1])
          # category_id는 class 명에 따라 0부터 순차적으로 부여. 
          category_id = self.coco_name_list.index(cat_name)
          #print('cat_name:', cat_name, 'category_id:', category_id)
          box = ['{:.6f}'.format(x) for x in obj[2]]
          box = ' '.join(box)
          line = str(category_id) + ' ' + box
          f.write(line + '\n')

  # ms-coco를 yolo format으로 변환. 
  def coco2yolo(self):
    print("loading image info...")
    images_info = self._load_images_info()
    print("loading done, total images", len(images_info))

    print("start converting...")
    anno_dict = self._convert_anno(images_info)
    print("converting done, total labels", len(anno_dict))

    print("saving txt file...")
    self._save_txt(anno_dict)
    print("saving done")

# %%
# !jq . /content/BCCD_Dataset/BCCD/val.json > output_val.json
# !cat output_val.json
# Out:
# {
#   "images": [
#     {
#       "file_name": "BloodImage_00000.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00000"
#     },
#     {
#       "file_name": "BloodImage_00002.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00002"
#     },
#     {
#       "file_name": "BloodImage_00014.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00014"
#     },
#     {
#       "file_name": "BloodImage_00017.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00017"
#     },
#     {
#       "file_name": "BloodImage_00028.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00028"
#     },
#     {
#       "file_name": "BloodImage_00029.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00029"
#     },
#     {
#       "file_name": "BloodImage_00030.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00030"
#     },
#     {
#       "file_name": "BloodImage_00035.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00035"
#     },
#     {
#       "file_name": "BloodImage_00037.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00037"
#     },
#     {
#       "file_name": "BloodImage_00053.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00053"
#     },
#     {
#       "file_name": "BloodImage_00055.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00055"
#     },
#     {
#       "file_name": "BloodImage_00064.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00064"
#     },
#     {
#       "file_name": "BloodImage_00066.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00066"
#     },
#     {
#       "file_name": "BloodImage_00072.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00072"
#     },
#     {
#       "file_name": "BloodImage_00073.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00073"
#     },
#     {
#       "file_name": "BloodImage_00089.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00089"
#     },
#     {
#       "file_name": "BloodImage_00099.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00099"
#     },
#     {
#       "file_name": "BloodImage_00104.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00104"
#     },
#     {
#       "file_name": "BloodImage_00109.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00109"
#     },
#     {
#       "file_name": "BloodImage_00111.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00111"
#     },
#     {
#       "file_name": "BloodImage_00115.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00115"
#     },
#     {
#       "file_name": "BloodImage_00125.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00125"
#     },
#     {
#       "file_name": "BloodImage_00130.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00130"
#     },
#     {
#       "file_name": "BloodImage_00140.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00140"
#     },
#     {
#       "file_name": "BloodImage_00143.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00143"
#     },
#     {
#       "file_name": "BloodImage_00145.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00145"
#     },
#     {
#       "file_name": "BloodImage_00147.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00147"
#     },
#     {
#       "file_name": "BloodImage_00148.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00148"
#     },
#     {
#       "file_name": "BloodImage_00152.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00152"
#     },
#     {
#       "file_name": "BloodImage_00162.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00162"
#     },
#     {
#       "file_name": "BloodImage_00183.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00183"
#     },
#     {
#       "file_name": "BloodImage_00192.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00192"
#     },
#     {
#       "file_name": "BloodImage_00193.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00193"
#     },
#     {
#       "file_name": "BloodImage_00207.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00207"
#     },
#     {
#       "file_name": "BloodImage_00209.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00209"
#     },
#     {
#       "file_name": "BloodImage_00216.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00216"
#     },
#     {
#       "file_name": "BloodImage_00217.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00217"
#     },
#     {
#       "file_name": "BloodImage_00218.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00218"
#     },
#     {
#       "file_name": "BloodImage_00219.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00219"
#     },
#     {
#       "file_name": "BloodImage_00221.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00221"
#     },
#     {
#       "file_name": "BloodImage_00222.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00222"
#     },
#     {
#       "file_name": "BloodImage_00223.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00223"
#     },
#     {
#       "file_name": "BloodImage_00228.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00228"
#     },
#     {
#       "file_name": "BloodImage_00230.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00230"
#     },
#     {
#       "file_name": "BloodImage_00236.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00236"
#     },
#     {
#       "file_name": "BloodImage_00241.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00241"
#     },
#     {
#       "file_name": "BloodImage_00244.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00244"
#     },
#     {
#       "file_name": "BloodImage_00245.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00245"
#     },
#     {
#       "file_name": "BloodImage_00246.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00246"
#     },
#     {
#       "file_name": "BloodImage_00255.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00255"
#     },
#     {
#       "file_name": "BloodImage_00260.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00260"
#     },
#     {
#       "file_name": "BloodImage_00261.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00261"
#     },
#     {
#       "file_name": "BloodImage_00262.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00262"
#     },
#     {
#       "file_name": "BloodImage_00269.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00269"
#     },
#     {
#       "file_name": "BloodImage_00272.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00272"
#     },
#     {
#       "file_name": "BloodImage_00274.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00274"
#     },
#     {
#       "file_name": "BloodImage_00277.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00277"
#     },
#     {
#       "file_name": "BloodImage_00285.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00285"
#     },
#     {
#       "file_name": "BloodImage_00298.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00298"
#     },
#     {
#       "file_name": "BloodImage_00304.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00304"
#     },
#     {
#       "file_name": "BloodImage_00310.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00310"
#     },
#     {
#       "file_name": "BloodImage_00312.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00312"
#     },
#     {
#       "file_name": "BloodImage_00315.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00315"
#     },
#     {
#       "file_name": "BloodImage_00326.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00326"
#     },
#     {
#       "file_name": "BloodImage_00330.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00330"
#     },
#     {
#       "file_name": "BloodImage_00331.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00331"
#     },
#     {
#       "file_name": "BloodImage_00334.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00334"
#     },
#     {
#       "file_name": "BloodImage_00337.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00337"
#     },
#     {
#       "file_name": "BloodImage_00338.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00338"
#     },
#     {
#       "file_name": "BloodImage_00340.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00340"
#     },
#     {
#       "file_name": "BloodImage_00342.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00342"
#     },
#     {
#       "file_name": "BloodImage_00349.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00349"
#     },
#     {
#       "file_name": "BloodImage_00350.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00350"
#     },
#     {
#       "file_name": "BloodImage_00352.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00352"
#     },
#     {
#       "file_name": "BloodImage_00367.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00367"
#     },
#     {
#       "file_name": "BloodImage_00368.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00368"
#     },
#     {
#       "file_name": "BloodImage_00381.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00381"
#     },
#     {
#       "file_name": "BloodImage_00383.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00383"
#     },
#     {
#       "file_name": "BloodImage_00386.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00386"
#     },
#     {
#       "file_name": "BloodImage_00389.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00389"
#     },
#     {
#       "file_name": "BloodImage_00392.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00392"
#     },
#     {
#       "file_name": "BloodImage_00396.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00396"
#     },
#     {
#       "file_name": "BloodImage_00397.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00397"
#     },
#     {
#       "file_name": "BloodImage_00398.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00398"
#     },
#     {
#       "file_name": "BloodImage_00402.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00402"
#     },
#     {
#       "file_name": "BloodImage_00409.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00409"
#     },
#     {
#       "file_name": "BloodImage_00410.jpg",
#       "height": 480,
#       "width": 640,
#       "id": "BloodImage_00410"
#     }
#   ],
#   "type": "instances",
#   "annotations": [
#     {
#       "area": 46400,
#       "iscrowd": 0,
#       "bbox": [
#         259,
#         176,
#         232,
#         200
#       ],
#       "category_id": 1,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00000",
#       "id": 1
#     },
#     {
#       "area": 10700,
#       "iscrowd": 0,
#       "bbox": [
#         77,
#         335,
#         107,
#         100
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00000",
#       "id": 2
#     },
#     {
#       "area": 10700,
#       "iscrowd": 0,
#       "bbox": [
#         62,
#         236,
#         107,
#         100
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00000",
#       "id": 3
#     },
#     {
#       "area": 10700,
#       "iscrowd": 0,
#       "bbox": [
#         213,
#         361,
#         107,
#         100
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00000",
#       "id": 4
#     },
#     {
#       "area": 8742,
#       "iscrowd": 0,
#       "bbox": [
#         413,
#         351,
#         93,
#         94
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00000",
#       "id": 5
#     },
#     {
#       "area": 8600,
#       "iscrowd": 0,
#       "bbox": [
#         554,
#         355,
#         86,
#         100
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00000",
#       "id": 6
#     },
#     {
#       "area": 6831,
#       "iscrowd": 0,
#       "bbox": [
#         468,
#         411,
#         99,
#         69
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00000",
#       "id": 7
#     },
#     {
#       "area": 9135,
#       "iscrowd": 0,
#       "bbox": [
#         0,
#         332,
#         87,
#         105
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00000",
#       "id": 8
#     },
#     {
#       "area": 6900,
#       "iscrowd": 0,
#       "bbox": [
#         3,
#         405,
#         92,
#         75
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00000",
#       "id": 9
#     },
#     {
#       "area": 9393,
#       "iscrowd": 0,
#       "bbox": [
#         154,
#         73,
#         93,
#         101
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00000",
#       "id": 10
#     },
#     {
#       "area": 7426,
#       "iscrowd": 0,
#       "bbox": [
#         10,
#         83,
#         94,
#         79
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00000",
#       "id": 11
#     },
#     {
#       "area": 10706,
#       "iscrowd": 0,
#       "bbox": [
#         533,
#         38,
#         106,
#         101
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00000",
#       "id": 12
#     },
#     {
#       "area": 9494,
#       "iscrowd": 0,
#       "bbox": [
#         546,
#         194,
#         94,
#         101
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00000",
#       "id": 13
#     },
#     {
#       "area": 9494,
#       "iscrowd": 0,
#       "bbox": [
#         387,
#         10,
#         94,
#         101
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00000",
#       "id": 14
#     },
#     {
#       "area": 9494,
#       "iscrowd": 0,
#       "bbox": [
#         170,
#         174,
#         94,
#         101
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00000",
#       "id": 15
#     },
#     {
#       "area": 9545,
#       "iscrowd": 0,
#       "bbox": [
#         259,
#         0,
#         115,
#         83
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00000",
#       "id": 16
#     },
#     {
#       "area": 9660,
#       "iscrowd": 0,
#       "bbox": [
#         228,
#         90,
#         115,
#         84
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00000",
#       "id": 17
#     },
#     {
#       "area": 10672,
#       "iscrowd": 0,
#       "bbox": [
#         68,
#         143,
#         116,
#         92
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00000",
#       "id": 18
#     },
#     {
#       "area": 11300,
#       "iscrowd": 0,
#       "bbox": [
#         481,
#         130,
#         113,
#         100
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00000",
#       "id": 19
#     },
#     {
#       "area": 8536,
#       "iscrowd": 0,
#       "bbox": [
#         367,
#         88,
#         97,
#         88
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00000",
#       "id": 20
#     },
#     {
#       "area": 14039,
#       "iscrowd": 0,
#       "bbox": [
#         384,
#         97,
#         139,
#         101
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00002",
#       "id": 21
#     },
#     {
#       "area": 11252,
#       "iscrowd": 0,
#       "bbox": [
#         383,
#         163,
#         116,
#         97
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00002",
#       "id": 22
#     },
#     {
#       "area": 12772,
#       "iscrowd": 0,
#       "bbox": [
#         100,
#         119,
#         124,
#         103
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00002",
#       "id": 23
#     },
#     {
#       "area": 10500,
#       "iscrowd": 0,
#       "bbox": [
#         129,
#         343,
#         105,
#         100
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00002",
#       "id": 24
#     },
#     {
#       "area": 9400,
#       "iscrowd": 0,
#       "bbox": [
#         160,
#         380,
#         94,
#         100
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00002",
#       "id": 25
#     },
#     {
#       "area": 12870,
#       "iscrowd": 0,
#       "bbox": [
#         13,
#         227,
#         110,
#         117
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00002",
#       "id": 26
#     },
#     {
#       "area": 12870,
#       "iscrowd": 0,
#       "bbox": [
#         305,
#         292,
#         110,
#         117
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00002",
#       "id": 27
#     },
#     {
#       "area": 12138,
#       "iscrowd": 0,
#       "bbox": [
#         530,
#         102,
#         102,
#         119
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00002",
#       "id": 28
#     },
#     {
#       "area": 11730,
#       "iscrowd": 0,
#       "bbox": [
#         491,
#         232,
#         102,
#         115
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00002",
#       "id": 29
#     },
#     {
#       "area": 11730,
#       "iscrowd": 0,
#       "bbox": [
#         363,
#         260,
#         102,
#         115
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00002",
#       "id": 30
#     },
#     {
#       "area": 11730,
#       "iscrowd": 0,
#       "bbox": [
#         263,
#         59,
#         102,
#         115
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00002",
#       "id": 31
#     },
#     {
#       "area": 14883,
#       "iscrowd": 0,
#       "bbox": [
#         248,
#         173,
#         121,
#         123
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00002",
#       "id": 32
#     },
#     {
#       "area": 30210,
#       "iscrowd": 0,
#       "bbox": [
#         282,
#         0,
#         285,
#         106
#       ],
#       "category_id": 1,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00002",
#       "id": 33
#     },
#     {
#       "area": 9212,
#       "iscrowd": 0,
#       "bbox": [
#         108,
#         0,
#         94,
#         98
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00002",
#       "id": 34
#     },
#     {
#       "area": 9306,
#       "iscrowd": 0,
#       "bbox": [
#         134,
#         65,
#         94,
#         99
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00002",
#       "id": 35
#     },
#     {
#       "area": 11877,
#       "iscrowd": 0,
#       "bbox": [
#         479,
#         373,
#         111,
#         107
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00002",
#       "id": 36
#     },
#     {
#       "area": 20592,
#       "iscrowd": 0,
#       "bbox": [
#         235,
#         210,
#         144,
#         143
#       ],
#       "category_id": 1,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00014",
#       "id": 37
#     },
#     {
#       "area": 9595,
#       "iscrowd": 0,
#       "bbox": [
#         157,
#         139,
#         101,
#         95
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00014",
#       "id": 38
#     },
#     {
#       "area": 12240,
#       "iscrowd": 0,
#       "bbox": [
#         77,
#         333,
#         120,
#         102
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00014",
#       "id": 39
#     },
#     {
#       "area": 7632,
#       "iscrowd": 0,
#       "bbox": [
#         0,
#         136,
#         72,
#         106
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00014",
#       "id": 40
#     },
#     {
#       "area": 12120,
#       "iscrowd": 0,
#       "bbox": [
#         32,
#         88,
#         120,
#         101
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00014",
#       "id": 41
#     },
#     {
#       "area": 12120,
#       "iscrowd": 0,
#       "bbox": [
#         52,
#         14,
#         120,
#         101
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00014",
#       "id": 42
#     },
#     {
#       "area": 6603,
#       "iscrowd": 0,
#       "bbox": [
#         335,
#         0,
#         71,
#         93
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00014",
#       "id": 43
#     },
#     {
#       "area": 12096,
#       "iscrowd": 0,
#       "bbox": [
#         296,
#         77,
#         126,
#         96
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00014",
#       "id": 44
#     },
#     {
#       "area": 14964,
#       "iscrowd": 0,
#       "bbox": [
#         223,
#         75,
#         129,
#         116
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00014",
#       "id": 45
#     },
#     {
#       "area": 12120,
#       "iscrowd": 0,
#       "bbox": [
#         214,
#         379,
#         120,
#         101
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00014",
#       "id": 46
#     },
#     {
#       "area": 8372,
#       "iscrowd": 0,
#       "bbox": [
#         355,
#         302,
#         92,
#         91
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00014",
#       "id": 47
#     },
#     {
#       "area": 8372,
#       "iscrowd": 0,
#       "bbox": [
#         392,
#         214,
#         92,
#         91
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00014",
#       "id": 48
#     },
#     {
#       "area": 7350,
#       "iscrowd": 0,
#       "bbox": [
#         447,
#         405,
#         98,
#         75
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00014",
#       "id": 49
#     },
#     {
#       "area": 12648,
#       "iscrowd": 0,
#       "bbox": [
#         430,
#         0,
#         124,
#         102
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00014",
#       "id": 50
#     },
#     {
#       "area": 1760,
#       "iscrowd": 0,
#       "bbox": [
#         361,
#         388,
#         44,
#         40
#       ],
#       "category_id": 3,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00014",
#       "id": 51
#     },
#     {
#       "area": 1760,
#       "iscrowd": 0,
#       "bbox": [
#         232,
#         339,
#         44,
#         40
#       ],
#       "category_id": 3,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00014",
#       "id": 52
#     },
#     {
#       "area": 9879,
#       "iscrowd": 0,
#       "bbox": [
#         541,
#         288,
#         89,
#         111
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00014",
#       "id": 53
#     },
#     {
#       "area": 6572,
#       "iscrowd": 0,
#       "bbox": [
#         578,
#         130,
#         62,
#         106
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00014",
#       "id": 54
#     },
#     {
#       "area": 10058,
#       "iscrowd": 0,
#       "bbox": [
#         524,
#         69,
#         94,
#         107
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00014",
#       "id": 55
#     },
#     {
#       "area": 36993,
#       "iscrowd": 0,
#       "bbox": [
#         127,
#         214,
#         209,
#         177
#       ],
#       "category_id": 1,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00017",
#       "id": 56
#     },
#     {
#       "area": 10573,
#       "iscrowd": 0,
#       "bbox": [
#         405,
#         175,
#         109,
#         97
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00017",
#       "id": 57
#     },
#     {
#       "area": 12099,
#       "iscrowd": 0,
#       "bbox": [
#         399,
#         72,
#         111,
#         109
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00017",
#       "id": 58
#     },
#     {
#       "area": 8585,
#       "iscrowd": 0,
#       "bbox": [
#         214,
#         86,
#         85,
#         101
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00017",
#       "id": 59
#     },
#     {
#       "area": 11187,
#       "iscrowd": 0,
#       "bbox": [
#         434,
#         301,
#         113,
#         99
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00017",
#       "id": 60
#     },
#     {
#       "area": 11187,
#       "iscrowd": 0,
#       "bbox": [
#         423,
#         353,
#         113,
#         99
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00017",
#       "id": 61
#     },
#     {
#       "area": 9345,
#       "iscrowd": 0,
#       "bbox": [
#         130,
#         381,
#         105,
#         89
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00017",
#       "id": 62
#     },
#     {
#       "area": 9345,
#       "iscrowd": 0,
#       "bbox": [
#         480,
#         163,
#         105,
#         89
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00017",
#       "id": 63
#     },
#     {
#       "area": 9800,
#       "iscrowd": 0,
#       "bbox": [
#         4,
#         334,
#         98,
#         100
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00017",
#       "id": 64
#     },
#     {
#       "area": 5565,
#       "iscrowd": 0,
#       "bbox": [
#         0,
#         100,
#         53,
#         105
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00017",
#       "id": 65
#     },
#     {
#       "area": 9000,
#       "iscrowd": 0,
#       "bbox": [
#         220,
#         389,
#         120,
#         75
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00017",
#       "id": 66
#     },
#     {
#       "area": 8820,
#       "iscrowd": 0,
#       "bbox": [
#         155,
#         0,
#         105,
#         84
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00017",
#       "id": 67
#     },
#     {
#       "area": 11227,
#       "iscrowd": 0,
#       "bbox": [
#         278,
#         36,
#         103,
#         109
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00017",
#       "id": 68
#     },
#     {
#       "area": 8178,
#       "iscrowd": 0,
#       "bbox": [
#         527,
#         0,
#         94,
#         87
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00017",
#       "id": 69
#     },
#     {
#       "area": 8272,
#       "iscrowd": 0,
#       "bbox": [
#         487,
#         10,
#         94,
#         88
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00017",
#       "id": 70
#     },
#     {
#       "area": 11227,
#       "iscrowd": 0,
#       "bbox": [
#         3,
#         244,
#         103,
#         109
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00017",
#       "id": 71
#     },
#     {
#       "area": 11227,
#       "iscrowd": 0,
#       "bbox": [
#         321,
#         334,
#         103,
#         109
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00017",
#       "id": 72
#     },
#     {
#       "area": 1254,
#       "iscrowd": 0,
#       "bbox": [
#         381,
#         46,
#         38,
#         33
#       ],
#       "category_id": 3,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00017",
#       "id": 73
#     },
#     {
#       "area": 28160,
#       "iscrowd": 0,
#       "bbox": [
#         254,
#         0,
#         176,
#         160
#       ],
#       "category_id": 1,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00028",
#       "id": 74
#     },
#     {
#       "area": 8928,
#       "iscrowd": 0,
#       "bbox": [
#         223,
#         176,
#         93,
#         96
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00028",
#       "id": 75
#     },
#     {
#       "area": 10608,
#       "iscrowd": 0,
#       "bbox": [
#         327,
#         289,
#         104,
#         102
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00028",
#       "id": 76
#     },
#     {
#       "area": 10608,
#       "iscrowd": 0,
#       "bbox": [
#         202,
#         307,
#         104,
#         102
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00028",
#       "id": 77
#     },
#     {
#       "area": 13268,
#       "iscrowd": 0,
#       "bbox": [
#         0,
#         280,
#         107,
#         124
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00028",
#       "id": 78
#     },
#     {
#       "area": 13392,
#       "iscrowd": 0,
#       "bbox": [
#         142,
#         117,
#         108,
#         124
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00028",
#       "id": 79
#     },
#     {
#       "area": 8400,
#       "iscrowd": 0,
#       "bbox": [
#         0,
#         97,
#         70,
#         120
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00028",
#       "id": 80
#     },
#     {
#       "area": 7216,
#       "iscrowd": 0,
#       "bbox": [
#         0,
#         184,
#         82,
#         88
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00028",
#       "id": 81
#     },
#     {
#       "area": 7304,
#       "iscrowd": 0,
#       "bbox": [
#         88,
#         242,
#         83,
#         88
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00028",
#       "id": 82
#     },
#     {
#       "area": 8496,
#       "iscrowd": 0,
#       "bbox": [
#         128,
#         408,
#         118,
#         72
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00028",
#       "id": 83
#     },
#     {
#       "area": 10608,
#       "iscrowd": 0,
#       "bbox": [
#         165,
#         220,
#         104,
#         102
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00028",
#       "id": 84
#     },
#     {
#       "area": 6936,
#       "iscrowd": 0,
#       "bbox": [
#         118,
#         0,
#         102,
#         68
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00028",
#       "id": 85
#     },
#     {
#       "area": 4860,
#       "iscrowd": 0,
#       "bbox": [
#         191,
#         0,
#         81,
#         60
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00028",
#       "id": 86
#     },
#     {
#       "area": 10500,
#       "iscrowd": 0,
#       "bbox": [
#         386,
#         166,
#         105,
#         100
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00028",
#       "id": 87
#     },
#     {
#       "area": 4745,
#       "iscrowd": 0,
#       "bbox": [
#         440,
#         194,
#         65,
#         73
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00028",
#       "id": 88
#     },
#     {
#       "area": 9135,
#       "iscrowd": 0,
#       "bbox": [
#         552,
#         180,
#         87,
#         105
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00028",
#       "id": 89
#     },
#     {
#       "area": 9135,
#       "iscrowd": 0,
#       "bbox": [
#         533,
#         227,
#         87,
#         105
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00028",
#       "id": 90
#     },
#     {
#       "area": 10353,
#       "iscrowd": 0,
#       "bbox": [
#         552,
#         361,
#         87,
#         119
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00028",
#       "id": 91
#     },
#     {
#       "area": 9152,
#       "iscrowd": 0,
#       "bbox": [
#         552,
#         0,
#         88,
#         104
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00028",
#       "id": 92
#     },
#     {
#       "area": 16226,
#       "iscrowd": 0,
#       "bbox": [
#         461,
#         57,
#         122,
#         133
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00028",
#       "id": 93
#     },
#     {
#       "area": 12519,
#       "iscrowd": 0,
#       "bbox": [
#         384,
#         74,
#         117,
#         107
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00028",
#       "id": 94
#     },
#     {
#       "area": 15129,
#       "iscrowd": 0,
#       "bbox": [
#         265,
#         327,
#         123,
#         123
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00028",
#       "id": 95
#     },
#     {
#       "area": 20550,
#       "iscrowd": 0,
#       "bbox": [
#         74,
#         178,
#         150,
#         137
#       ],
#       "category_id": 1,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00029",
#       "id": 96
#     },
#     {
#       "area": 1960,
#       "iscrowd": 0,
#       "bbox": [
#         439,
#         282,
#         56,
#         35
#       ],
#       "category_id": 3,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00029",
#       "id": 97
#     },
#     {
#       "area": 13452,
#       "iscrowd": 0,
#       "bbox": [
#         240,
#         85,
#         118,
#         114
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00029",
#       "id": 98
#     },
#     {
#       "area": 7790,
#       "iscrowd": 0,
#       "bbox": [
#         211,
#         47,
#         82,
#         95
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00029",
#       "id": 99
#     },
#     {
#       "area": 8600,
#       "iscrowd": 0,
#       "bbox": [
#         363,
#         142,
#         100,
#         86
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00029",
#       "id": 100
#     },
#     {
#       "area": 11224,
#       "iscrowd": 0,
#       "bbox": [
#         423,
#         136,
#         122,
#         92
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00029",
#       "id": 101
#     },
#     {
#       "area": 13176,
#       "iscrowd": 0,
#       "bbox": [
#         226,
#         192,
#         122,
#         108
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00029",
#       "id": 102
#     },
#     {
#       "area": 13176,
#       "iscrowd": 0,
#       "bbox": [
#         206,
#         264,
#         122,
#         108
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00029",
#       "id": 103
#     },
#     {
#       "area": 13176,
#       "iscrowd": 0,
#       "bbox": [
#         138,
#         319,
#         122,
#         108
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00029",
#       "id": 104
#     },
#     {
#       "area": 13176,
#       "iscrowd": 0,
#       "bbox": [
#         255,
#         364,
#         122,
#         108
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00029",
#       "id": 105
#     },
#     {
#       "area": 13176,
#       "iscrowd": 0,
#       "bbox": [
#         389,
#         355,
#         122,
#         108
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00029",
#       "id": 106
#     },
#     {
#       "area": 10353,
#       "iscrowd": 0,
#       "bbox": [
#         505,
#         109,
#         119,
#         87
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00029",
#       "id": 107
#     },
#     {
#       "area": 11224,
#       "iscrowd": 0,
#       "bbox": [
#         516,
#         56,
#         122,
#         92
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00029",
#       "id": 108
#     },
#     {
#       "area": 10600,
#       "iscrowd": 0,
#       "bbox": [
#         420,
#         7,
#         106,
#         100
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00029",
#       "id": 109
#     },
#     {
#       "area": 16113,
#       "iscrowd": 0,
#       "bbox": [
#         69,
#         22,
#         131,
#         123
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00029",
#       "id": 110
#     },
#     {
#       "area": 12987,
#       "iscrowd": 0,
#       "bbox": [
#         18,
#         69,
#         111,
#         117
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00029",
#       "id": 111
#     },
#     {
#       "area": 10788,
#       "iscrowd": 0,
#       "bbox": [
#         0,
#         127,
#         87,
#         124
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00029",
#       "id": 112
#     },
#     {
#       "area": 9875,
#       "iscrowd": 0,
#       "bbox": [
#         0,
#         193,
#         79,
#         125
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00029",
#       "id": 113
#     },
#     {
#       "area": 7725,
#       "iscrowd": 0,
#       "bbox": [
#         0,
#         263,
#         75,
#         103
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00029",
#       "id": 114
#     },
#     {
#       "area": 7725,
#       "iscrowd": 0,
#       "bbox": [
#         0,
#         309,
#         75,
#         103
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00029",
#       "id": 115
#     },
#     {
#       "area": 8610,
#       "iscrowd": 0,
#       "bbox": [
#         23,
#         354,
#         82,
#         105
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00029",
#       "id": 116
#     },
#     {
#       "area": 5394,
#       "iscrowd": 0,
#       "bbox": [
#         10,
#         422,
#         93,
#         58
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00029",
#       "id": 117
#     },
#     {
#       "area": 4794,
#       "iscrowd": 0,
#       "bbox": [
#         206,
#         0,
#         94,
#         51
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00029",
#       "id": 118
#     },
#     {
#       "area": 6734,
#       "iscrowd": 0,
#       "bbox": [
#         274,
#         0,
#         91,
#         74
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00029",
#       "id": 119
#     },
#     {
#       "area": 20449,
#       "iscrowd": 0,
#       "bbox": [
#         0,
#         190,
#         143,
#         143
#       ],
#       "category_id": 1,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00030",
#       "id": 120
#     },
#     {
#       "area": 13176,
#       "iscrowd": 0,
#       "bbox": [
#         122,
#         248,
#         108,
#         122
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00030",
#       "id": 121
#     },
#     {
#       "area": 8667,
#       "iscrowd": 0,
#       "bbox": [
#         148,
#         112,
#         81,
#         107
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00030",
#       "id": 122
#     },
#     {
#       "area": 8667,
#       "iscrowd": 0,
#       "bbox": [
#         197,
#         116,
#         81,
#         107
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00030",
#       "id": 123
#     },
#     {
#       "area": 6090,
#       "iscrowd": 0,
#       "bbox": [
#         194,
#         57,
#         70,
#         87
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00030",
#       "id": 124
#     },
#     {
#       "area": 10044,
#       "iscrowd": 0,
#       "bbox": [
#         290,
#         269,
#         93,
#         108
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00030",
#       "id": 125
#     },
#     {
#       "area": 8374,
#       "iscrowd": 0,
#       "bbox": [
#         323,
#         401,
#         106,
#         79
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00030",
#       "id": 126
#     },
#     {
#       "area": 8374,
#       "iscrowd": 0,
#       "bbox": [
#         358,
#         401,
#         106,
#         79
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00030",
#       "id": 127
#     },
#     {
#       "area": 9996,
#       "iscrowd": 0,
#       "bbox": [
#         374,
#         238,
#         98,
#         102
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00030",
#       "id": 128
#     },
#     {
#       "area": 9996,
#       "iscrowd": 0,
#       "bbox": [
#         456,
#         190,
#         98,
#         102
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00030",
#       "id": 129
#     },
#     {
#       "area": 12168,
#       "iscrowd": 0,
#       "bbox": [
#         298,
#         173,
#         117,
#         104
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00030",
#       "id": 130
#     },
#     {
#       "area": 9306,
#       "iscrowd": 0,
#       "bbox": [
#         457,
#         386,
#         99,
#         94
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00030",
#       "id": 131
#     },
#     {
#       "area": 7800,
#       "iscrowd": 0,
#       "bbox": [
#         0,
#         321,
#         75,
#         104
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00030",
#       "id": 132
#     },
#     {
#       "area": 8643,
#       "iscrowd": 0,
#       "bbox": [
#         0,
#         62,
#         67,
#         129
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00030",
#       "id": 133
#     },
#     {
#       "area": 10692,
#       "iscrowd": 0,
#       "bbox": [
#         296,
#         0,
#         132,
#         81
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00030",
#       "id": 134
#     },
#     {
#       "area": 9996,
#       "iscrowd": 0,
#       "bbox": [
#         499,
#         237,
#         98,
#         102
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00030",
#       "id": 135
#     },
#     {
#       "area": 9996,
#       "iscrowd": 0,
#       "bbox": [
#         484,
#         280,
#         98,
#         102
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00030",
#       "id": 136
#     },
#     {
#       "area": 9996,
#       "iscrowd": 0,
#       "bbox": [
#         472,
#         337,
#         98,
#         102
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00030",
#       "id": 137
#     },
#     {
#       "area": 6900,
#       "iscrowd": 0,
#       "bbox": [
#         571,
#         355,
#         69,
#         100
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00030",
#       "id": 138
#     },
#     {
#       "area": 16472,
#       "iscrowd": 0,
#       "bbox": [
#         524,
#         6,
#         116,
#         142
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00030",
#       "id": 139
#     },
#     {
#       "area": 14250,
#       "iscrowd": 0,
#       "bbox": [
#         444,
#         34,
#         114,
#         125
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00030",
#       "id": 140
#     },
#     {
#       "area": 2021,
#       "iscrowd": 0,
#       "bbox": [
#         346,
#         90,
#         43,
#         47
#       ],
#       "category_id": 3,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00030",
#       "id": 141
#     },
#     {
#       "area": 2021,
#       "iscrowd": 0,
#       "bbox": [
#         404,
#         85,
#         43,
#         47
#       ],
#       "category_id": 3,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00030",
#       "id": 142
#     },
#     {
#       "area": 2021,
#       "iscrowd": 0,
#       "bbox": [
#         300,
#         22,
#         43,
#         47
#       ],
#       "category_id": 3,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00030",
#       "id": 143
#     },
#     {
#       "area": 11877,
#       "iscrowd": 0,
#       "bbox": [
#         285,
#         122,
#         111,
#         107
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00030",
#       "id": 144
#     },
#     {
#       "area": 21432,
#       "iscrowd": 0,
#       "bbox": [
#         182,
#         284,
#         152,
#         141
#       ],
#       "category_id": 1,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00035",
#       "id": 145
#     },
#     {
#       "area": 13375,
#       "iscrowd": 0,
#       "bbox": [
#         159,
#         154,
#         107,
#         125
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00035",
#       "id": 146
#     },
#     {
#       "area": 13125,
#       "iscrowd": 0,
#       "bbox": [
#         0,
#         28,
#         105,
#         125
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00035",
#       "id": 147
#     },
#     {
# ...
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00398",
#       "id": 1076
#     },
#     {
#       "area": 12546,
#       "iscrowd": 0,
#       "bbox": [
#         166,
#         347,
#         123,
#         102
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00398",
#       "id": 1077
#     },
#     {
#       "area": 9506,
#       "iscrowd": 0,
#       "bbox": [
#         350,
#         5,
#         97,
#         98
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00398",
#       "id": 1078
#     },
#     {
#       "area": 11094,
#       "iscrowd": 0,
#       "bbox": [
#         403,
#         85,
#         129,
#         86
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00398",
#       "id": 1079
#     },
#     {
#       "area": 12091,
#       "iscrowd": 0,
#       "bbox": [
#         449,
#         373,
#         113,
#         107
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00398",
#       "id": 1080
#     },
#     {
#       "area": 13312,
#       "iscrowd": 0,
#       "bbox": [
#         434,
#         258,
#         128,
#         104
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00398",
#       "id": 1081
#     },
#     {
#       "area": 12480,
#       "iscrowd": 0,
#       "bbox": [
#         22,
#         376,
#         120,
#         104
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00398",
#       "id": 1082
#     },
#     {
#       "area": 9506,
#       "iscrowd": 0,
#       "bbox": [
#         159,
#         9,
#         97,
#         98
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00398",
#       "id": 1083
#     },
#     {
#       "area": 9506,
#       "iscrowd": 0,
#       "bbox": [
#         508,
#         146,
#         97,
#         98
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00398",
#       "id": 1084
#     },
#     {
#       "area": 7546,
#       "iscrowd": 0,
#       "bbox": [
#         473,
#         0,
#         98,
#         77
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00398",
#       "id": 1085
#     },
#     {
#       "area": 46176,
#       "iscrowd": 0,
#       "bbox": [
#         186,
#         43,
#         208,
#         222
#       ],
#       "category_id": 1,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00398",
#       "id": 1086
#     },
#     {
#       "area": 10504,
#       "iscrowd": 0,
#       "bbox": [
#         10,
#         42,
#         101,
#         104
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00402",
#       "id": 1087
#     },
#     {
#       "area": 13696,
#       "iscrowd": 0,
#       "bbox": [
#         0,
#         165,
#         107,
#         128
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00402",
#       "id": 1088
#     },
#     {
#       "area": 9603,
#       "iscrowd": 0,
#       "bbox": [
#         92,
#         326,
#         97,
#         99
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00402",
#       "id": 1089
#     },
#     {
#       "area": 12987,
#       "iscrowd": 0,
#       "bbox": [
#         107,
#         175,
#         117,
#         111
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00402",
#       "id": 1090
#     },
#     {
#       "area": 12987,
#       "iscrowd": 0,
#       "bbox": [
#         220,
#         40,
#         117,
#         111
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00402",
#       "id": 1091
#     },
#     {
#       "area": 9672,
#       "iscrowd": 0,
#       "bbox": [
#         347,
#         376,
#         93,
#         104
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00402",
#       "id": 1092
#     },
#     {
#       "area": 10504,
#       "iscrowd": 0,
#       "bbox": [
#         170,
#         376,
#         101,
#         104
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00402",
#       "id": 1093
#     },
#     {
#       "area": 12376,
#       "iscrowd": 0,
#       "bbox": [
#         328,
#         146,
#         119,
#         104
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00402",
#       "id": 1094
#     },
#     {
#       "area": 7600,
#       "iscrowd": 0,
#       "bbox": [
#         458,
#         28,
#         80,
#         95
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00402",
#       "id": 1095
#     },
#     {
#       "area": 11128,
#       "iscrowd": 0,
#       "bbox": [
#         507,
#         147,
#         107,
#         104
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00402",
#       "id": 1096
#     },
#     {
#       "area": 8649,
#       "iscrowd": 0,
#       "bbox": [
#         545,
#         40,
#         93,
#         93
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00402",
#       "id": 1097
#     },
#     {
#       "area": 14042,
#       "iscrowd": 0,
#       "bbox": [
#         336,
#         249,
#         118,
#         119
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00402",
#       "id": 1098
#     },
#     {
#       "area": 9898,
#       "iscrowd": 0,
#       "bbox": [
#         261,
#         134,
#         101,
#         98
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00402",
#       "id": 1099
#     },
#     {
#       "area": 2254,
#       "iscrowd": 0,
#       "bbox": [
#         295,
#         242,
#         46,
#         49
#       ],
#       "category_id": 3,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00402",
#       "id": 1100
#     },
#     {
#       "area": 35530,
#       "iscrowd": 0,
#       "bbox": [
#         453,
#         267,
#         187,
#         190
#       ],
#       "category_id": 1,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00402",
#       "id": 1101
#     },
#     {
#       "area": 9494,
#       "iscrowd": 0,
#       "bbox": [
#         517,
#         167,
#         94,
#         101
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00409",
#       "id": 1102
#     },
#     {
#       "area": 14112,
#       "iscrowd": 0,
#       "bbox": [
#         425,
#         86,
#         126,
#         112
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00409",
#       "id": 1103
#     },
#     {
#       "area": 12540,
#       "iscrowd": 0,
#       "bbox": [
#         501,
#         297,
#         110,
#         114
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00409",
#       "id": 1104
#     },
#     {
#       "area": 13786,
#       "iscrowd": 0,
#       "bbox": [
#         249,
#         244,
#         122,
#         113
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00409",
#       "id": 1105
#     },
#     {
#       "area": 12656,
#       "iscrowd": 0,
#       "bbox": [
#         57,
#         103,
#         113,
#         112
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00409",
#       "id": 1106
#     },
#     {
#       "area": 14097,
#       "iscrowd": 0,
#       "bbox": [
#         377,
#         257,
#         127,
#         111
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00409",
#       "id": 1107
#     },
#     {
#       "area": 8556,
#       "iscrowd": 0,
#       "bbox": [
#         227,
#         125,
#         93,
#         92
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00409",
#       "id": 1108
#     },
#     {
#       "area": 8556,
#       "iscrowd": 0,
#       "bbox": [
#         168,
#         78,
#         93,
#         92
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00409",
#       "id": 1109
#     },
#     {
#       "area": 7636,
#       "iscrowd": 0,
#       "bbox": [
#         1,
#         0,
#         92,
#         83
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00409",
#       "id": 1110
#     },
#     {
#       "area": 9010,
#       "iscrowd": 0,
#       "bbox": [
#         15,
#         228,
#         106,
#         85
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00409",
#       "id": 1111
#     },
#     {
#       "area": 11445,
#       "iscrowd": 0,
#       "bbox": [
#         6,
#         262,
#         109,
#         105
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00409",
#       "id": 1112
#     },
#     {
#       "area": 17280,
#       "iscrowd": 0,
#       "bbox": [
#         348,
#         126,
#         108,
#         160
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00409",
#       "id": 1113
#     },
#     {
#       "area": 9702,
#       "iscrowd": 0,
#       "bbox": [
#         437,
#         0,
#         126,
#         77
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00409",
#       "id": 1114
#     },
#     {
#       "area": 6720,
#       "iscrowd": 0,
#       "bbox": [
#         226,
#         70,
#         84,
#         80
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00409",
#       "id": 1115
#     },
#     {
#       "area": 1672,
#       "iscrowd": 0,
#       "bbox": [
#         412,
#         395,
#         44,
#         38
#       ],
#       "category_id": 3,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00409",
#       "id": 1116
#     },
#     {
#       "area": 1716,
#       "iscrowd": 0,
#       "bbox": [
#         333,
#         209,
#         44,
#         39
#       ],
#       "category_id": 3,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00409",
#       "id": 1117
#     },
#     {
#       "area": 1666,
#       "iscrowd": 0,
#       "bbox": [
#         179,
#         168,
#         34,
#         49
#       ],
#       "category_id": 3,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00409",
#       "id": 1118
#     },
#     {
#       "area": 1665,
#       "iscrowd": 0,
#       "bbox": [
#         77,
#         14,
#         45,
#         37
#       ],
#       "category_id": 3,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00409",
#       "id": 1119
#     },
#     {
#       "area": 43052,
#       "iscrowd": 0,
#       "bbox": [
#         77,
#         292,
#         229,
#         188
#       ],
#       "category_id": 1,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00409",
#       "id": 1120
#     },
#     {
#       "area": 9010,
#       "iscrowd": 0,
#       "bbox": [
#         232,
#         367,
#         106,
#         85
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00410",
#       "id": 1121
#     },
#     {
#       "area": 10212,
#       "iscrowd": 0,
#       "bbox": [
#         345,
#         384,
#         111,
#         92
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00410",
#       "id": 1122
#     },
#     {
#       "area": 10212,
#       "iscrowd": 0,
#       "bbox": [
#         240,
#         72,
#         111,
#         92
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00410",
#       "id": 1123
#     },
#     {
#       "area": 9945,
#       "iscrowd": 0,
#       "bbox": [
#         249,
#         0,
#         117,
#         85
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00410",
#       "id": 1124
#     },
#     {
#       "area": 13794,
#       "iscrowd": 0,
#       "bbox": [
#         105,
#         314,
#         121,
#         114
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00410",
#       "id": 1125
#     },
#     {
#       "area": 9010,
#       "iscrowd": 0,
#       "bbox": [
#         288,
#         159,
#         106,
#         85
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00410",
#       "id": 1126
#     },
#     {
#       "area": 9010,
#       "iscrowd": 0,
#       "bbox": [
#         349,
#         108,
#         106,
#         85
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00410",
#       "id": 1127
#     },
#     {
#       "area": 9010,
#       "iscrowd": 0,
#       "bbox": [
#         103,
#         19,
#         106,
#         85
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00410",
#       "id": 1128
#     },
#     {
#       "area": 11016,
#       "iscrowd": 0,
#       "bbox": [
#         0,
#         220,
#         108,
#         102
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00410",
#       "id": 1129
#     },
#     {
#       "area": 5916,
#       "iscrowd": 0,
#       "bbox": [
#         581,
#         378,
#         58,
#         102
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00410",
#       "id": 1130
#     },
#     {
#       "area": 9010,
#       "iscrowd": 0,
#       "bbox": [
#         456,
#         371,
#         106,
#         85
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00410",
#       "id": 1131
#     },
#     {
#       "area": 7332,
#       "iscrowd": 0,
#       "bbox": [
#         562,
#         19,
#         78,
#         94
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00410",
#       "id": 1132
#     },
#     {
#       "area": 12222,
#       "iscrowd": 0,
#       "bbox": [
#         303,
#         261,
#         97,
#         126
#       ],
#       "category_id": 2,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00410",
#       "id": 1133
#     },
#     {
#       "area": 2491,
#       "iscrowd": 0,
#       "bbox": [
#         238,
#         274,
#         53,
#         47
#       ],
#       "category_id": 3,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00410",
#       "id": 1134
#     },
#     {
#       "area": 4209,
#       "iscrowd": 0,
#       "bbox": [
#         120,
#         259,
#         69,
#         61
#       ],
#       "category_id": 3,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00410",
#       "id": 1135
#     },
#     {
#       "area": 2352,
#       "iscrowd": 0,
#       "bbox": [
#         56,
#         118,
#         48,
#         49
#       ],
#       "category_id": 3,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00410",
#       "id": 1136
#     },
#     {
#       "area": 1218,
#       "iscrowd": 0,
#       "bbox": [
#         0,
#         285,
#         29,
#         42
#       ],
#       "category_id": 3,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00410",
#       "id": 1137
#     },
#     {
#       "area": 56105,
#       "iscrowd": 0,
#       "bbox": [
#         366,
#         165,
#         245,
#         229
#       ],
#       "category_id": 1,
#       "ignore": 0,
#       "segmentation": [],
#       "image_id": "BloodImage_00410",
#       "id": 1138
#     }
#   ],
#   "categories": [
#     {
#       "supercategory": "none",
#       "id": 1,
#       "name": "WBC"
#     },
#     {
#       "supercategory": "none",
#       "id": 2,
#       "name": "RBC"
#     },
#     {
#       "supercategory": "none",
#       "id": 3,
#       "name": "Platelets"
#     }
#   ]
# }

# %%
# 학습/검증/테스트용 images, labels 디렉토리 생성. 
# !mkdir /content/bccd;
# !cd /content/bccd; mkdir images; mkdir labels;
# !cd /content/bccd/images; mkdir train; mkdir val; mkdir test
# !cd /content/bccd/labels; mkdir train; mkdir val; mkdir test

# %%
# train 용 yolo 데이터 세트 생성. 
train_yolo_converter = COCO2YOLO(src_img_dir='/content/BCCD_Dataset/BCCD/JPEGImages', json_file='/content/BCCD_Dataset/BCCD/train.json',
                                 tgt_img_dir='/content/bccd/images/train', tgt_anno_dir='/content/bccd/labels/train')
train_yolo_converter.coco2yolo()

# val 용 yolo 데이터 세트 생성. 
val_yolo_converter = COCO2YOLO(src_img_dir='/content/BCCD_Dataset/BCCD/JPEGImages', json_file='/content/BCCD_Dataset/BCCD/val.json',
                                 tgt_img_dir='/content/bccd/images/val', tgt_anno_dir='/content/bccd/labels/val')
val_yolo_converter.coco2yolo()

# test 용 yolo 데이터 세트 생성. 
test_yolo_converter = COCO2YOLO(src_img_dir='/content/BCCD_Dataset/BCCD/JPEGImages', json_file='/content/BCCD_Dataset/BCCD/test.json',
                                 tgt_img_dir='/content/bccd/images/test', tgt_anno_dir='/content/bccd/labels/test')
test_yolo_converter.coco2yolo()
# Out:
# total images 205
# total categories 3
# total labels 2805
# loading image info...
# loading done, total images 205
# start converting...
# converting done, total labels 205
# saving txt file...
# saving done
# total images 87
# total categories 3
# total labels 1138
# loading image info...
# loading done, total images 87
# start converting...
# converting done, total labels 87
# saving txt file...
# saving done
# total images 72
# total categories 3
# total labels 945
# loading image info...
# loading done, total images 72
# start converting...
# converting done, total labels 72
# saving txt file...
# saving done

# %% [markdown]
# ### Dataset용 yaml 파일을 생성하고 학습 수행
# * yolo v5는 모델이 yolov5s(small), yolov5m(middle), yolov5l(large), yolov5x(extra large)로 되어있음. weight 인자값으로 이들중 하나를 입력해 줌

# %%
# !wget -O /content/bccd/bccd.yaml https://raw.githubusercontent.com/chulminkw/DLCV/master/data/util/bccd.yaml
# Out:
# --2021-06-10 05:18:05--  https://raw.githubusercontent.com/chulminkw/DLCV/master/data/util/bccd.yaml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 184 [text/plain]
# Saving to: ‘/content/bccd/bccd.yaml’
#
# /content/bccd/bccd. 100%[===================>]     184  --.-KB/s    in 0s
#
# 2021-06-10 05:18:06 (12.3 MB/s) - ‘/content/bccd/bccd.yaml’ saved [184/184]

# %%
# Google Drive 접근을 위한 Mount 적용. 
import os, sys 
from google.colab import drive 

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# soft link로 Google Drive Directory 연결. 
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Google Drive 밑에 Directory 생성. 이미 생성 되어 있을 시 오류 발생. 
# !mkdir "/mydrive/ultra_workdir"
# Out:
#  강의				      sea_depth.zip
#  101_ObjectCategories		      test_colab01.ipynb
#  application_test.csv		      Training400
#  application_train.csv		      ultra_workdir
#  bkup				      Untitled
# 'Colab Notebooks'		      Untitled0.ipynb
#  credit_card_balance.csv	      Untitled10.ipynb
#  download			      Untitled11.ipynb
#  HomeCredit_columns_description.csv   Untitled12.ipynb
#  installments_payments.csv	      Untitled13.ipynb
#  kaggle.json			      Untitled14.ipynb
#  melanoma_jpeg.zip		      Untitled1.ipynb
#  models				      Untitled2.ipynb
#  models_imsi			      Untitled3.ipynb
# 'My Drive'			      Untitled4.ipynb
#  pet_work_dir			      Untitled5.ipynb
#  POS_CASH_balance.csv		      Untitled6.ipynb
#  President.ipynb		      Untitled7.ipynb
#  previous_application.csv	      Untitled8.ipynb
#  sample_submission.csv		      Untitled9.ipynb
#  sea_depth			      VOC
# mkdir: cannot create directory ‘/mydrive/ultra_workdir’: File exists

# %%
###  10번 미만 epoch는 좋은 성능이 안나옴. 최소 30번 이상 epoch 적용. large 모델 적용 시 batch size가 8보다 클 경우 colab에서 memory 부족 발생.
### 혈소판의 경우 상대적으로 mAP:0.5~0.95 Detection 성능이 좋지 못함. 백혈구 만큼 학습데이터가 적은것도 이유지만, Object 사이즈가 상대적으로 작음.   
# !cd /content/yolov5; python train.py --img 640 --batch 8 --epochs 30 --data /content/bccd/bccd.yaml --weights yolov5l.pt \
                                     --project=/mydrive/ultra_workdir --name bccd --exist-ok
# Out:
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v5.0-174-g4695ca8 torch 1.8.1+cu101 CUDA:0 (Tesla V100-SXM2-16GB, 16160.5MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=8, bbox_interval=-1, bucket='', cache_images=False, cfg='', data='/content/bccd/bccd.yaml', device='', entity=None, epochs=30, evolve=False, exist_ok=True, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='bccd', noautoanchor=False, nosave=False, notest=False, project='/mydrive/ultra_workdir', quad=False, rect=False, resume=False, save_dir='/mydrive/ultra_workdir/bccd', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=8, upload_dataset=False, weights='yolov5l.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir /mydrive/ultra_workdir', view at http://localhost:6006/
# 2021-06-10 05:22:04.419401: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# hyperparameters: lr0=0.01, lrf=0.2, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0
# wandb: Install Weights & Biases for YOLOv5 logging with 'pip install wandb' (recommended)
# Downloading https://github.com/ultralytics/yolov5/releases/download/v5.0/yolov5l.pt to yolov5l.pt...
# 100% 90.2M/90.2M [00:04<00:00, 20.9MB/s]
#
# Overriding model.yaml nc=80 with nc=3
#
#                  from  n    params  module                                  arguments
#   0                -1  1      7040  models.common.Focus                     [3, 64, 3]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  1    156928  models.common.C3                        [128, 128, 3]
#   3                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   4                -1  1   1611264  models.common.C3                        [256, 256, 9]
#   5                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   6                -1  1   6433792  models.common.C3                        [512, 512, 9]
#   7                -1  1   4720640  models.common.Conv                      [512, 1024, 3, 2]
#   8                -1  1   2624512  models.common.SPP                       [1024, 1024, [5, 9, 13]]
#   9                -1  1   9971712  models.common.C3                        [1024, 1024, 3, False]
#  10                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1   2757632  models.common.C3                        [1024, 512, 3, False]
#  14                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1    690688  models.common.C3                        [512, 256, 3, False]
#  18                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1   2495488  models.common.C3                        [512, 512, 3, False]
#  21                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   9971712  models.common.C3                        [1024, 1024, 3, False]
#  24      [17, 20, 23]  1     43080  models.yolo.Detect                      [3, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [256, 512, 1024]]
# Model Summary: 499 layers, 46642120 parameters, 46642120 gradients, 114.3 GFLOPs
#
# Transferred 644/650 items from yolov5l.pt
# Scaled weight_decay = 0.0005
# Optimizer groups: 110 .bias, 110 conv.weight, 107 other
# train: Scanning '/content/bccd/labels/train' images and labels...205 found, 0 missing, 0 empty, 0 corrupted: 100% 205/205 [00:00<00:00, 2112.15it/s]
# train: New cache created: /content/bccd/labels/train.cache
# val: Scanning '/content/bccd/labels/val' images and labels...87 found, 0 missing, 0 empty, 0 corrupted: 100% 87/87 [00:00<00:00, 1134.09it/s]
# val: New cache created: /content/bccd/labels/val.cache
# Plotting labels...
#
# autoanchor: Analyzing anchors... anchors/target = 5.76, Best Possible Recall (BPR) = 0.9996
# Image sizes 640 train, 640 test
# Using 2 dataloader workers
# Logging results to /mydrive/ultra_workdir/bccd
# Starting training for 30 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       0/29     5.42G    0.1092    0.1629   0.03989     0.312       200       640: 100% 26/26 [00:15<00:00,  1.63it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:04<00:00,  1.38it/s]
#                  all         87       1138     0.0395     0.0917     0.0219    0.00411
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       1/29     5.37G   0.09316    0.1851   0.03568     0.314       132       640: 100% 26/26 [00:06<00:00,  4.11it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:02<00:00,  2.45it/s]
#                  all         87       1138     0.0915      0.138     0.0644      0.014
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       2/29     5.37G   0.08138    0.1884   0.02994    0.2998        98       640: 100% 26/26 [00:05<00:00,  4.48it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:02<00:00,  2.06it/s]
#                  all         87       1138      0.779      0.133      0.102     0.0278
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       3/29     5.37G   0.07401    0.1708   0.02435    0.2691       148       640: 100% 26/26 [00:05<00:00,  4.60it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:02<00:00,  2.39it/s]
#                  all         87       1138       0.78      0.189      0.114     0.0431
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       4/29     5.37G   0.06401    0.1685   0.01952     0.252        79       640: 100% 26/26 [00:05<00:00,  4.67it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:02<00:00,  2.87it/s]
#                  all         87       1138       0.82      0.197      0.209     0.0778
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       5/29     5.37G   0.05594    0.1647   0.01682    0.2374       202       640: 100% 26/26 [00:05<00:00,  4.71it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:01<00:00,  3.51it/s]
#                  all         87       1138      0.401      0.503      0.427      0.208
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       6/29     5.37G   0.05192    0.1609   0.01573    0.2285       133       640: 100% 26/26 [00:05<00:00,  4.52it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:01<00:00,  4.32it/s]
#                  all         87       1138      0.513      0.706      0.646      0.272
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       7/29     5.37G   0.04984    0.1489   0.01409    0.2128       126       640: 100% 26/26 [00:05<00:00,  4.64it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:01<00:00,  4.88it/s]
#                  all         87       1138      0.489      0.658      0.567      0.207
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       8/29     5.37G   0.05151    0.1516   0.01295    0.2161        96       640: 100% 26/26 [00:06<00:00,  4.32it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:01<00:00,  4.00it/s]
#                  all         87       1138      0.439      0.819      0.605       0.24
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       9/29     5.37G   0.05219    0.1522   0.01213    0.2165       154       640: 100% 26/26 [00:05<00:00,  4.95it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:01<00:00,  4.12it/s]
#                  all         87       1138      0.615      0.761      0.708      0.276
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      10/29     5.37G   0.04837    0.1538   0.01107    0.2133       134       640: 100% 26/26 [00:05<00:00,  4.75it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:01<00:00,  4.21it/s]
#                  all         87       1138       0.57      0.862      0.748       0.41
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      11/29     5.37G   0.04912    0.1452  0.009664     0.204        93       640: 100% 26/26 [00:05<00:00,  4.69it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:01<00:00,  4.55it/s]
#                  all         87       1138       0.65      0.776      0.738       0.36
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      12/29     5.37G   0.04778    0.1423  0.008298    0.1984       133       640: 100% 26/26 [00:06<00:00,  4.27it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:01<00:00,  5.14it/s]
#                  all         87       1138      0.542      0.704      0.635      0.296
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      13/29     5.37G   0.04731    0.1481  0.007218    0.2026       144       640: 100% 26/26 [00:05<00:00,  4.88it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:01<00:00,  4.41it/s]
#                  all         87       1138      0.479      0.818      0.636      0.359
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      14/29     5.37G    0.0501    0.1518  0.006959    0.2088       137       640: 100% 26/26 [00:05<00:00,  4.91it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:01<00:00,  4.87it/s]
#                  all         87       1138      0.678       0.73      0.732      0.361
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      15/29     5.37G   0.04914    0.1446   0.00594    0.1997       120       640: 100% 26/26 [00:05<00:00,  5.10it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:01<00:00,  4.62it/s]
#                  all         87       1138       0.35       0.76      0.479       0.21
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      16/29     5.37G   0.04926    0.1327  0.005536    0.1875       172       640: 100% 26/26 [00:05<00:00,  4.88it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:01<00:00,  4.93it/s]
#                  all         87       1138      0.489      0.841      0.731      0.419
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      17/29     5.37G   0.04635    0.1466  0.004721    0.1977       141       640: 100% 26/26 [00:05<00:00,  4.98it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:01<00:00,  4.18it/s]
#                  all         87       1138      0.493      0.798      0.648      0.333
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      18/29     5.37G   0.04439    0.1395  0.004889    0.1888       194       640: 100% 26/26 [00:05<00:00,  4.42it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:01<00:00,  4.60it/s]
#                  all         87       1138      0.633      0.809      0.802      0.438
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      19/29     5.37G   0.04821    0.1502  0.004474    0.2029       152       640: 100% 26/26 [00:05<00:00,  4.98it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:01<00:00,  5.10it/s]
#                  all         87       1138       0.55      0.773      0.649      0.331
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      20/29     5.37G   0.04557    0.1419  0.004417    0.1919       144       640: 100% 26/26 [00:05<00:00,  4.93it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:01<00:00,  4.76it/s]
#                  all         87       1138      0.549      0.752       0.69      0.387
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      21/29     5.37G   0.04147    0.1316    0.0044    0.1775       139       640: 100% 26/26 [00:05<00:00,  4.99it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:01<00:00,  4.81it/s]
#                  all         87       1138      0.737      0.873      0.887      0.539
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      22/29     5.37G   0.04122    0.1433  0.004055    0.1886        86       640: 100% 26/26 [00:05<00:00,  4.89it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:01<00:00,  4.77it/s]
#                  all         87       1138      0.705      0.857      0.819      0.455
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      23/29     5.37G   0.03909    0.1328  0.003785    0.1757       112       640: 100% 26/26 [00:05<00:00,  4.98it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:01<00:00,  4.95it/s]
#                  all         87       1138      0.679      0.876       0.79      0.456
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      24/29     5.37G   0.03982    0.1311  0.003636    0.1745        89       640: 100% 26/26 [00:05<00:00,  5.04it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:01<00:00,  4.67it/s]
#                  all         87       1138      0.415      0.761      0.625      0.297
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      25/29     5.37G    0.0435    0.1359  0.003348    0.1827       153       640: 100% 26/26 [00:05<00:00,  5.04it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:01<00:00,  5.05it/s]
#                  all         87       1138      0.736      0.783      0.853      0.475
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      26/29     5.37G   0.03993    0.1364  0.003547    0.1799        91       640: 100% 26/26 [00:05<00:00,  5.07it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:01<00:00,  5.08it/s]
#                  all         87       1138      0.739      0.815      0.845      0.483
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      27/29     5.37G   0.03908    0.1384  0.003679    0.1811       111       640: 100% 26/26 [00:06<00:00,  4.32it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:01<00:00,  4.74it/s]
#                  all         87       1138      0.892      0.833       0.91      0.587
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      28/29     5.37G   0.03585    0.1347  0.003478     0.174       162       640: 100% 26/26 [00:05<00:00,  5.09it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:01<00:00,  4.79it/s]
#                  all         87       1138       0.83      0.868      0.895      0.567
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      29/29     5.37G   0.03639    0.1336  0.003245    0.1732       102       640: 100% 26/26 [00:05<00:00,  5.01it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:02<00:00,  2.35it/s]
#                  all         87       1138      0.856      0.857      0.909      0.527
#                  WBC         87         87      0.932          1      0.991      0.737
#                  RBC         87        968      0.848      0.728      0.877      0.472
#            Platelets         87         83      0.786      0.843       0.86      0.373
# 30 epochs completed in 0.088 hours.
#
# Optimizer stripped from /mydrive/ultra_workdir/bccd/weights/last.pt, 93.8MB
# Optimizer stripped from /mydrive/ultra_workdir/bccd/weights/best.pt, 93.8MB

# %%
from collections import Counter

anno_list = train_yolo_converter.labels['annotations']
category_list = [x['category_id'] for x in anno_list]

Counter(category_list)
# Out:
# Counter({1: 214, 2: 2382, 3: 209})

# %% [markdown]
# ### 단일 이미지 inference 수행 및 테스트 데이터 세트 evaluation

# %%
# image 파일 inference 
# !cd /content/yolov5;python detect.py --source /content/bccd/images/test/BloodImage_00011.jpg \
                            --weights /mydrive/ultra_workdir/bccd/weights/best.pt --conf 0.2 \
                            --project=/content/data/output --name=run_image --exist-ok --line-thickness 2
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.2, device='', exist_ok=True, half=False, hide_conf=False, hide_labels=False, imgsz=640, iou_thres=0.45, line_thickness=2, max_det=1000, name='run_image', nosave=False, project='/content/data/output', save_conf=False, save_crop=False, save_txt=False, source='/content/bccd/images/test/BloodImage_00011.jpg', update=False, view_img=False, weights=['/mydrive/ultra_workdir/bccd/weights/best.pt'])
# YOLOv5 🚀 v5.0-174-g4695ca8 torch 1.8.1+cu101 CUDA:0 (Tesla V100-SXM2-16GB, 16160.5MB)
#
# Fusing layers...
# Model Summary: 392 layers, 46611336 parameters, 0 gradients, 114.1 GFLOPs
# image 1/1 /content/bccd/images/test/BloodImage_00011.jpg: 480x640 1 WBC, 21 RBCs, 1 Platelets, Done. (0.014s)
# Results saved to /content/data/output/run_image
# Done. (0.049s)

# %%
# !cd /content/yolov5; python test.py --weights /mydrive/ultra_workdir/bccd/weights/best.pt  --data /content/bccd/bccd.yaml \
                           --project /content/data/output --name=test_result --exist-ok --img 640 --iou 0.65
# Out:
# Namespace(augment=False, batch_size=32, conf_thres=0.001, data='/content/bccd/bccd.yaml', device='', exist_ok=True, half=False, imgsz=640, iou_thres=0.65, name='test_result', project='/content/data/output', save_conf=False, save_hybrid=False, save_json=False, save_txt=False, single_cls=False, task='val', verbose=False, weights=['/mydrive/ultra_workdir/bccd/weights/best.pt'])
# YOLOv5 🚀 v5.0-174-g4695ca8 torch 1.8.1+cu101 CUDA:0 (Tesla V100-SXM2-16GB, 16160.5MB)
#
# Fusing layers...
# Model Summary: 392 layers, 46611336 parameters, 0 gradients, 114.1 GFLOPs
# val: Scanning '/content/bccd/labels/val.cache' images and labels... 87 found, 0 missing, 0 empty, 0 corrupted: 100% 87/87 [00:00<00:00, 786432.00it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 3/3 [00:03<00:00,  1.18s/it]
#                  all         87       1138      0.872      0.826      0.895      0.579
#                  WBC         87         87      0.982          1      0.986      0.768
#                  RBC         87        968      0.819      0.685      0.845       0.56
#            Platelets         87         83      0.815      0.794      0.854      0.408
# Speed: 0.1ms pre-process, 7.2ms inference, 3.2ms NMS per image at shape (32, 3, 640, 640)
# Results saved to /content/data/output/test_result
